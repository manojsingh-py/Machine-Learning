# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/house_price.csv', usecols=['GarageQual', 'FireplaceQu', 'SalePrice'])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()
# Out:
# FireplaceQu    0.472603
# GarageQual     0.055479
# SalePrice      0.000000
# dtype: float64

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts()
# Out:
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
df['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
# Imputing with the most frequent value
df['GarageQual'].fillna(df['GarageQual'].mode()[0], inplace=True)
df['FireplaceQu'].fillna(df['FireplaceQu'].mode()[0], inplace=True)

# %%
df.isnull().mean()
# Out:
# FireplaceQu    0.472603
# GarageQual     0.055479
# SalePrice      0.000000
# dtype: float64

# %%
# Imputing with the most frequent value + creating a new feature to capture the missingness
df = pd.read_csv('../datasets/house_price.csv', usecols=['GarageQual', 'FireplaceQu', 'SalePrice'])
df['GarageQual'].fillna(df['GarageQual'].mode()[0], inplace=True)
df['FireplaceQu'].fillna(df['FireplaceQu'].mode()[0], inplace=True)
df['GarageQual_missing'] = np.where(df['GarageQual'].isnull(), 1, 0)
df['FireplaceQu_missing'] = np.where(df['FireplaceQu'].isnull(), 1, 0)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_22756\122094207.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageQual'].fillna(df['GarageQual'].mode()[0], inplace=True)
# C:\Users\manoj\AppData\Local\Temp\ipykernel_22756\122094207.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice  GarageQual_missing  FireplaceQu_missing
# 0          Gd         TA     208500                   0                    0
# 1          TA         TA     181500                   0                    0
# 2          TA         TA     223500                   0                    0
# 3          Gd         TA     140000                   0                    0
# 4          TA         TA     250000                   0                    0

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
df['GarageQual'].value_counts().plot(kind='bar')
plt.subplot(1,2,2)
df['FireplaceQu'].value_counts().plot(kind='bar')
plt.show()

# %%
df = pd.read_csv('../datasets/house_price.csv', usecols=['GarageQual', 'FireplaceQu', 'SalePrice'])

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde', ax=ax)

df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with TA', 'Houses with NA']
ax.legend(lines, labels, loc='best')

plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
temp = df[df['GarageQual']=='TA']['SalePrice']

# %%
df['GarageQual'].fillna('TA', inplace=True)
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

temp.plot(kind='kde', ax=ax)

# distribution of the variable after imputation
df[df['GarageQual'] == 'TA']['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')

# add title
plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde', ax=ax)

df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with Gd', 'Houses with NA']
ax.legend(lines, labels, loc='best')

plt.title('FireplaceQu')
# Out:
# Text(0.5, 1.0, 'FireplaceQu')

# %%
temp = df[df['FireplaceQu']=='Gd']['SalePrice']

# %%
df['FireplaceQu'].fillna('Gd', inplace=True)
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_22756\3028501272.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FireplaceQu'].fillna('Gd', inplace=True)
# <Axes: xlabel='FireplaceQu'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


temp.plot(kind='kde', ax=ax)

# distribution of the variable after imputation
df[df['FireplaceQu'] == 'Gd']['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')

# add title
plt.title('FireplaceQu')
# Out:
# Text(0.5, 1.0, 'FireplaceQu')

# %%
# Using Sklearn's SimpleImputer for frequent value imputation
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# %%
X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train.columns)
X_test_imputed = pd.DataFrame(X_test_imputed, columns=X_test.columns)

# %%
X_train_imputed.head()
# Out:
#   FireplaceQu GarageQual
# 0          Gd         TA
# 1          Gd         TA
# 2          Gd         TA
# 3          TA         TA
# 4          Gd         TA

# %%
X_test_imputed.head()
# Out:
#   FireplaceQu GarageQual
# 0          Gd         TA
# 1          TA         TA
# 2          Gd         TA
# 3          Gd         TA
# 4          Gd         TA

# %%
X_train_imputed['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
X_train_imputed['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
X_test_imputed['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
X_test_imputed['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
imputer.statistics_
# Out:
# array(['Gd', 'TA'], dtype=object)
