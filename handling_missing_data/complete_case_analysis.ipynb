# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/data_science_job.csv')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  18679 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  float64
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  training_hours          18392 non-null  float64
#  12  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index    experience  training_hours  \
# count  19158.000000            18679.000000  19093.000000    18392.000000
# mean   16875.358179                0.828951      9.928036       65.185787
# std     9616.292592                0.123334      6.505268       59.885626
# min        1.000000                0.448000      0.000000        1.000000
# 25%     8554.250000                0.740000      4.000000       23.000000
# 50%    16982.500000                0.903000      9.000000       47.000000
# 75%    25169.750000                0.920000     16.000000       88.000000
# max    33380.000000                0.949000     20.000000      336.000000
#
#              target
# count  19158.000000
# mean       0.249348
# std        0.432647
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
# 1. Complete Case Analysis
cols = [col for col in df.columns if df[col].isnull().mean() < 0.05 and df[col].isnull().mean() > 0]

# %%
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 1313                    0.624       no_enrollment        Graduate         8.0
# 7631                    0.939    Full time course        Graduate         9.0
# 1072                    0.920       no_enrollment        Graduate        20.0
# 2209                    0.624       no_enrollment        Graduate         6.0
# 12683                   0.743    Full time course         Masters         6.0
#
#        training_hours
# 1313             44.0
# 7631            166.0
# 1072             28.0
# 2209             50.0
# 12683            79.0

# %%
len(df[cols].dropna()) / len(df)
# Out:
# 0.8968577095730244

# %%
cca_df = df[cols].dropna()
df.shape, cca_df.shape
# Out:
# ((19158, 13), (17182, 5))

# %%
cca_df.hist(bins=50, density=True, figsize=(12,12))
plt.show()

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)

df['training_hours'].hist(bins=50, density=True, alpha=0.5, ax=ax, color='red')

cca_df['training_hours'].hist(bins=50, density=True, alpha=0.5, ax=ax, color='blue')
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original dataset
df['training_hours'].plot.density(color='red')

# dataset after cca
cca_df['training_hours'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original dataset
df['city_development_index'].hist(bins=50, ax=ax, density=True, color='red')

# dataset after cca, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distributions
cca_df['city_development_index'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original dataset
df['city_development_index'].plot.density(color='red')

# dataset after cca
cca_df['city_development_index'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original dataset
df['experience'].hist(bins=50, ax=ax, density=True, color='red')

# dataset after cca, the argument alpha makes the color transparent, so we can
# see the overlay of the 2 distributions
cca_df['experience'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original dataset
df['experience'].plot.density(color='red')

# dataset after cca
cca_df['experience'].plot.density(color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
temp = pd.concat([
            # percentage of observations per category, original dataset
            df['enrolled_university'].value_counts() / len(df),

            # percentage of observations per category, cca dataset
            cca_df['enrolled_university'].value_counts() / len(cca_df)
        ],
        axis=1)

# add column names
temp.columns = ['original', 'cca']

temp
# Out:
#                      original       cca
# enrolled_university
# no_enrollment        0.721213  0.735188
# Full time course     0.196106  0.200733
# Part time course     0.062533  0.064079

# %%
temp = pd.concat([
            # percentage of observations per category, original dataset
            df['education_level'].value_counts() / len(df),

            # percentage of observations per category, cca dataset
            cca_df['education_level'].value_counts() / len(cca_df)
        ],
        axis=1)

# add column names
temp.columns = ['original', 'cca']

temp
# Out:
#                  original       cca
# education_level
# Graduate         0.605387  0.619835
# Masters          0.227633  0.234082
# High School      0.105282  0.107380
# Phd              0.021610  0.022116
# Primary School   0.016077  0.016587
